# %% [markdown]
# Exercise 1: Visualization-Based Analysis of the Titanic Dataset\
# Abstract:
# Using the Seaborn Titanic dataset, perform exploratory data visualization to understand passenger survival patterns.
# 1. Visualize the frequency distribution of categorical variables such as sex, class, and embarkation port using appropriate plots.
# 2. Analyse the distribution of numerical variables such as age and fare using suitable distribution plots.
# 3. Examine the relationship between passenger class and fare using comparative plots.
# 4. Visualize survival rates with respect to gender and passenger class.
# 5. Interpret the visualizations and summarize the key insights regarding factors that influenced passenger survival.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
titanic = sns.load_dataset("titanic")

# %% [markdown]
# 1. Frequency distribution of categorical variables

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="sex", data=titanic)
plt.title("Gender Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="class", data=titanic)
plt.title("Class Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="embark_town", data=titanic)
plt.title("Embark Town Distribution")
plt.show()

# %% [markdown]
# 2. Distribution of numerical variables

# %%
plt.figure(figsize=(6,4))
sns.histplot(titanic["age"], kde=True)
plt.title("Age Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(titanic["fare"], kde=True)
plt.title("Fare Distribution")
plt.show()

# %% [markdown]
# 3. Relationship between class and fare

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x="class", y="fare", data=titanic)
plt.title("Fare vs Passenger Class")
plt.show()

# %% [markdown]
# 4. Survival rates by gender and class

# %%
plt.figure(figsize=(6,4))
sns.barplot(x="sex", y="survived", data=titanic)
plt.title("Survival Rate by Gender")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.barplot(x="class", y="survived", data=titanic)
plt.title("Survival Rate by Class")
plt.show()

# %% [markdown]
# 5. Multivariate visualization

# %%
sns.catplot(x="class", y="survived", hue="sex", data=titanic, kind="bar")
plt.title("Survival by Class and Gender")
plt.show()

# %% [markdown]
# Exercise 2: Visualization-Based Analysis of the Penguins Dataset\
# Abstract:
# Using the Seaborn Penguins dataset, perform exploratory data visualization to study physical characteristics across different penguin species.
# Tasks:
# 1. Visualize the distribution of numerical attributes such as bill length, bill depth, and body mass.
# 2. Compare physical characteristics across different species and sex using appropriate categorical–numerical plots.
# 3. Analyse the relationship between flipper length and body mass using relational plots.
# 4. Use multivariate visualizations to observe interactions among multiple attributes.
# 5. Draw meaningful inferences from the visual analysis and discuss observable patterns or differences among species.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
penguins = sns.load_dataset("penguins")

# %% [markdown]
# 1. Distribution of numerical attributes

# %%
plt.figure(figsize=(6,4))
sns.histplot(penguins["bill_length_mm"], kde=True)
plt.title("Bill Length Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(penguins["bill_depth_mm"], kde=True)
plt.title("Bill Depth Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(penguins["body_mass_g"], kde=True)
plt.title("Body Mass Distribution")
plt.show()

# %% [markdown]
# 2. Comparison across species and sex

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x="species", y="body_mass_g", hue="sex", data=penguins)
plt.title("Body Mass by Species and Sex")
plt.show()

# %% [markdown]
# 3. Relationship between flipper length and body mass

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x="flipper_length_mm", y="body_mass_g", hue="species", data=penguins)
plt.title("Flipper Length vs Body Mass")
plt.show()

# %% [markdown]
# 4. Multivariate visualization

# %%
sns.pairplot(penguins, hue="species")
plt.show()

# %% [markdown]
# 5. Violin plot for bill length

# %%
plt.figure(figsize=(6,4))
sns.violinplot(x="species", y="bill_length_mm", data=penguins)
plt.title("Bill Length by Species")
plt.show()
